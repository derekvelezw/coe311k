# %% [markdown]
# # Lets start with Hello World

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
x = 3+5
print(x)
# Out:
# 8

# %%
numIn = input("Please enter a number: ")
# Out:
# Please enter a number: 10

# %%
stringIn = input("Please enter a string: ")
# Out:
# Please enter a string: hi

# %%
print(stringIn)
# Out:
# hi

# %%
print("The number that you input was: ", numIn)
# Out:
# The number that you input was:  8

# %%
my_file = open("output_file.txt",'w')
var1 = "this is a string\n"
my_file.write(var1)
var2 = 10
my_file.write("\n")
my_file.write(str(var2))
var3 = 20.0
my_file.write("\n")
my_file.write(str(var3))
my_file.close()

# %%
my_file = open("output_file.txt",'r')
content = my_file.read()
print(content)
my_file.close()
# Out:
# this is a string
#
# 10
# 20.0
